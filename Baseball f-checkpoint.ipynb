# %% [markdown]
# # Base Ball Case Study

# %% [markdown]
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input features:----
# Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
#
# Output:-----
# Number of predicted wins (W)

# %% [markdown]
# # Importing Neccessary Libreries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# 1)----This dataset contins 16 features
#
# 2)----'w' is the target variable which predicts the number of wins
#
# 3)----all the features contains numerical data, that means we co go for Regression model.

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset contains  30  Rows and  17  Columns

# %%
#Checking  for null values
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing values in any of the feature

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# 1) ---- No missing values
#
# 2)----- Earned run avarage(ERA) contains float values rest of the columns contains integer values.

# %%
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# checking the unique value of all the column
data.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
#checking the uniqueness of target column
data['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the unique values present in target variable 'w'

# %%
#List of values in target variable
data['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# # Description Of Dataset

# %%
#Checking 5 point summary of dataset
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This is the statical description of dataset, from above observation we can conclude that summary of dataset is good, as it doesnot contain any negative values.
#
# 1)---Count of all the features are same i.e 30 which is equal to number of rows that mean this dataset has no null values.
#
# 2)---['R', '2B', 'BB', 'SO', 'RA', 'ER','ERA', 'SHO', ], These columns are having median more than mean, that means it is left skewed.
#
# 3) --the column '3B' AND 'SB', are having same median and mean, that means data is normal.
#
# 4)---['AB', 'H', 'HR', 'SV', 'E'] these columns are having mean greater than median, that means data is right skewed.
#
# 5)---From above observations it is clear that outliers are present in dataset.

# %%
# Heat map, for statistics of the column
plt.figure(figsize =(25,10))
sns.heatmap(data.describe(), annot = True, linewidths=.1, fmt='.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %%
# histogram plotting for target column
sns.histplot(data['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# from the above plot we can conclude that--
# 1)----Min wins of the team is 63
#
# 2)----Max wins of the team is 100
#
# 3)----min count of win is between 70 to 75
#
# 4)----max count of win is between 75 to 80
#
# 5)---- skewness is not present in this target column, data is noramilised.

# %% [markdown]
# # scatterplot and their observations

# %%
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['R'],data['E'], hue=data['W'])
plt.xlabel('Runs')
plt.ylabel('Error')
plt.title('Comparision between runs and error')
# Out:
# Text(0.5, 1.0, 'Comparision between runs and error')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['RA'],data['ERA'], hue=data['W'])
plt.xlabel('Runs allowed')
plt.ylabel('Earned runs avg')
plt.title('Comparision between Runs Allowed and Earned runs avg')
# Out:
# Text(0.5, 1.0, 'Comparision between Runs Allowed and Earned runs avg')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['R'],data['H'], hue=data['W'])
plt.xlabel('Runs')
plt.ylabel('Hits')
plt.title('Comparision between runs and Hits')
# Out:
# Text(0.5, 1.0, 'Comparision between runs and Hits')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['AB'],data['H'], hue=data['W'])
plt.xlabel('At bats')
plt.ylabel('Hits')
plt.title('Comparision between At bats and Hits')
# Out:
# Text(0.5, 1.0, 'Comparision between At bats and Hits')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['R'],data['W'], hue=data['W'])
plt.xlabel('Runs')
plt.ylabel('Wins')
plt.title('Comparision between runs and Wins')
# Out:
# Text(0.5, 1.0, 'Comparision between runs and Wins')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['RA'],data['W'], hue=data['W'])
plt.xlabel('Runs allowed')
plt.ylabel('Wins')
plt.title('Comparision between runs allowed and wins')
# Out:
# Text(0.5, 1.0, 'Comparision between runs allowed and wins')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['ERA'],data['W'], hue=data['W'])
plt.xlabel('Earned run avg')
plt.ylabel('Wins')
plt.title('Comparision between Earned runs avg and wins')
# Out:
# Text(0.5, 1.0, 'Comparision between Earned runs avg and wins')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['SV'],data['E'], hue=data['W'])
plt.xlabel('Saves')
plt.ylabel('Error')
plt.title('Comparision between Saves and error')
# Out:
# Text(0.5, 1.0, 'Comparision between Saves and error')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['SV'],data['W'], hue=data['W'])
plt.xlabel('Saves')
plt.ylabel('Wins')
plt.title('Comparision between Saves and Wins')
# Out:
# Text(0.5, 1.0, 'Comparision between Saves and Wins')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['AB'],data['W'], hue=data['W'])
plt.xlabel('Atbat')
plt.ylabel('Wins')
plt.title('Comparision between At bats and Win')
# Out:
# Text(0.5, 1.0, 'Comparision between At bats and Win')

# %%
plt.figure(figsize=(8,6))
sns.regplot(data['SHO'],data['W'])
plt.xlabel('Shutouts')
plt.ylabel('Win')
plt.title('Comparision between Shutouts and win')
# Out:
# Text(0.5, 1.0, 'Comparision between Shutouts and win')

# %%
plt.figure(figsize=(8,6))
sns.regplot(data['CG'],data['W'])
plt.xlabel('Complete Games')
plt.ylabel('Win')
plt.title('Comparision between Complete games and win')
# Out:
# Text(0.5, 1.0, 'Comparision between Complete games and win')

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data,hue='W')

# %% [markdown]
# From above obsevation we can observed the relationship between various feature and with target also

# %%
#data distribution in every column
plt.figure(figsize=(25,35),facecolor= 'blue')
plotnumber = 1


for column in data:
    if plotnumber<=18:
        plt.subplot(6,3,plotnumber)
        ax=sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# 1)----columnS( 'W', 'AB', '3B', 'SB', 'CG', 'ER') looks normally distributed and no skewness
#
# 2)---- columns ('BB', 'SO', 'ERA', 'RA', 'SHO') Looks like normally distributed but having skewness
#
# 3)----column 'R' is skewed to left
#
# 4)-----columns 'H', 'HR', 'SV', 'E' are skewed to right.

# %%
# coorelation between feature and label
data.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# VISUALIZATION USING HEAT MAP
plt.figure(figsize=(14,8))
sns.heatmap(data.corr(),linewidth=0.1, fmt='0.2f', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above plot we can conclude the following points--
#
# 1) the target column 'W'Is moderate negatively corelated with ('E, SB, 3B, AND AB)
#
# 2) the target column 'W' is highly negative corelated with ('ERA, 'ER', 'RA')
#
# 3) The target column 'W' is positively corelated with ('SV', 'SHO', 'BB', 'HR', '2B', 'R', 'SO )
#
# 4) If look at featute to feature relationship, it can be observed that column 'ERA', 'ER', 'RA' are highly corelated with each other(Multicolinear
#
#
#
#
# POSITIVELY CORELATED COLUMN
#
# SV,  SHO,  BB,  2B,  R,  HR,  CG,  SO
#
#
#
#
# NEGATIVELY CORELATED COLUMN
#
# AB,  3B,  SB,  RA,  ER,  ERA,  H,  E

# %% [markdown]
# ------>> From the above plot it can also be observed that columns 'H', 'CG', and 'AB' are very less corelation with target variable, so we can drop these column

# %%
data.drop(['H','CG','AB'],axis=1,inplace=True)
data.head(2)
# Out:
#     W    R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV   E
# 0  95  724  300  42  139  383   973  104  641  601  3.73    8  56  88
# 1  83  696  277  44  156  439  1264   70  700  653  4.07   12  45  86

# %%
data.shape
# Out:
# (30, 14)

# %% [markdown]
# # OUTLIERS

# %%
#data distribution in every column
plt.figure(figsize=(25,35),facecolor= 'blue')
plotnumber = 1


for column in data:
    if plotnumber<=15:
        plt.subplot(5,3,plotnumber)
        ax=sns.boxplot(data[column],orient='v')
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# from above plot it can be seen that column 'E', 'SV', 'SHO', 'R' and 'ERA' are having outlier and can be removed throgh zscore technique

# %%
#Removing outliers using zscore method
feature =data[['E','SV','SHO','R','ERA']]

# %%
from scipy.stats import zscore
z = np.abs(zscore(feature))
zn
# Out:
#            E        SV       SHO         R       ERA
# 0   0.461470  1.671607  0.814629  0.619078  0.506955
# 1   0.607197  0.249879  0.172800  0.134432  0.254598
# 2   1.117242  0.654856  0.320914  0.332906  0.641347
# 3   0.485758  0.784104  0.567771  1.146419  0.053010
# 4   0.607197  1.042600  0.172800  0.013270  1.531318
# 5   0.461470  1.171848  0.320914  3.509647  0.350165
# 6   0.097152  0.637623  1.802057  1.311430  0.165003
# 7   1.262970  0.008617  0.320914  0.428681  0.209800
# 8   0.048576  2.188598  0.172800  0.765626  0.484557
# 9   0.194303  0.396360  0.320914  1.034489  0.792164
# 10  1.797303  0.249879  0.567771  1.086415  0.635374
# 11  0.680061  0.525608  0.419657  0.705622  0.865333
# 12  0.097152  0.379127  0.172800  0.471376  0.036584
# 13  0.024288  0.249879  0.172800  0.557920  0.456185
# 14  2.307348  1.947335  0.913371  0.099814  0.411388
# 15  0.121439  2.447094  0.913371  0.713699  2.276445
# 16  2.015894  1.413111  0.419657  0.151740  1.671683
# ...

# %%
new_data = data[(z<3).all(axis=1)]
new_data
# Out:
#       W    R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0    95  724  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1    83  696  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2    81  669  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3    76  622  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4    74  689  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 6    87  764  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7    81  713  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 8    80  644  278  32  167  436  1310   87  642  604  3.74   12  60   95
# 9    78  748  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10   88  751  279  32  172  503  1233  101  733  680  4.24    9  45  119
# 11   86  729  278  26  230  486  1392  121  618  572  3.57   13  39   85
# 12   85  661  243  21  176  435  1150   52  675  630  3.94   12  46   93
# ...

# %% [markdown]
# This dataset is free from outliers

# %%
print(data.shape)
print(new_data.shape)
# Out:
# (30, 14)
# (29, 14)

# %%
data_loss = ((30-29)/30)*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# data loss in zscore is 3.33 % which is considerable, so can go with zscore technique

# %% [markdown]
# # checking for sckewness

# %%
new_data.skew()
# Out:
# W      0.119013
# R     -0.215364
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# if we consider (-0.65 to 0.65) as a considerable range for skewness then column 'E' has more skewness and column 'SV' has bit skewness

# %%
skewed = ['SV','E']

# %%
#Removing skewness using yeo-johnson method
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
new_data[skewed] = scaler.fit_transform(new_data[skewed].values)
new_data[skewed].head()
# Out:
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %%
new_data.skew()
# Out:
# W      0.119013
# R     -0.215364
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.526943
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# Now skewness has removed from all the columns

# %%
#data distribution in every column
plt.figure(figsize=(25,35),facecolor= 'blue')
plotnumber = 1


for column in new_data:
    if plotnumber<=18:
        plt.subplot(6,3,plotnumber)
        ax=sns.distplot(new_data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# from above graph , we can see that skewness has removed from all the features

# %% [markdown]
# # Data preprocessing

# %%
#separating feature and target
x = new_data.drop('W',axis=1)
y=new_data['W']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        2B        3B        HR        BB        SO        SB  \
# 0   0.959398  1.556538  1.010845 -0.765863 -1.536359 -2.727623  0.905953
# 1   0.331147  0.201171  1.208917 -0.181389 -0.495021  0.121896 -0.585315
# 2  -0.274666  1.733325 -0.276617 -0.697101  1.252941 -0.925866  0.116458
# 3  -1.329231 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246 -0.673037
# 4   0.174084  0.908319  1.704094 -0.353293 -0.197495  0.072935 -0.015124
# 5   1.856900 -0.093474 -1.266972  1.743939  1.643442 -0.240414 -0.892341
# 6   0.712585 -1.625627 -1.167936  1.915843 -0.885522  0.777970 -1.725697
# 7  -0.835605  0.260100  0.020490  0.196801 -0.550807  0.572335  0.160319
# 8   1.497899  1.202964  0.119526 -0.009484  0.230197 -1.013995 -0.541454
# 9   1.565212  0.319029  0.020490  0.368705  0.695081 -0.181661  0.774370
# 10  1.071586  0.260100 -0.573723  2.362794  0.378960  1.375292  1.651587
# 11 -0.454167 -1.802414 -1.068901  0.506228 -0.569402 -0.994411 -1.374810
# ...

# %%
# CHECK FOR MULTICOLINEARITY (VARIANCE INFLATION FACTOR)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     3.924352        R
# 1     2.480471       2B
# 2     3.231387       3B
# 3     6.034122       HR
# 4     2.515143       BB
# 5     2.805599       SO
# 6     1.801403       SB
# 7   176.098264       RA
# 8   569.982741       ER
# 9   315.787198      ERA
# 10    3.353615      SHO
# 11    2.957267       SV
# 12    1.739212        E

# %% [markdown]
# the value of VIF is more than 10 in columns ('RA, ER , ERA), Highest vif column can be drpoed

# %%
x.drop('ER', axis=1, inplace=True)

# %%
# checking for vif after removing 'ER'
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     3.872865        R
# 1     2.438468       2B
# 2     3.196472       3B
# 3     4.919049       HR
# 4     2.425562       BB
# 5     2.481798       SO
# 6     1.485283       SB
# 7    86.283312       RA
# 8    84.632576      ERA
# 9     2.911644      SHO
# 10    2.072629       SV
# 11    1.739199        E

# %%
x.drop('RA',axis=1, inplace= True)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     3.869911        R
# 1     2.380611       2B
# 2     3.167281       3B
# 3     4.531894       HR
# 4     2.269077       BB
# 5     2.050357       SO
# 6     1.471307       SB
# 7     3.693893      ERA
# 8     2.747804      SHO
# 9     1.936823       SV
# 10    1.382412        E

# %% [markdown]
# now we can see that value of VIF is less than 10 for all the columns

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
maxAcc = 0
maxRS = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=i)
    model = LinearRegression()
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print("Maximum r2 score is ",maxAcc,"at random state ",maxRS)
# Out:
# Maximum r2 score is  0.9324276150133912 at random state  50

# %%
x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
#checking r2 score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predLR))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predLR)))
# Out:
# R2_score: 0.9324276150133912
# MAE: 2.6128243198196497
# MSE: 9.697054359065936
# RMSE: 3.114009370420381

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01,0.1,1.0,10.26],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
ridge = Ridge()
clf = GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'sag'}

# %%
#checking r2 score for Ridge
ridge = Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge = ridge.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_ridge))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_ridge))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_ridge))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: 0.8283540148491055
# MAE: 4.320471423376592
# MSE: 24.632258412271565
# RMSE: 4.963089603490105

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso = Lasso()
clf = GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#checking r2 score for Lasso
lasso = Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso = lasso.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_lasso))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_lasso))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_lasso))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597
# RMSE: 4.41299065192299

# %%
#checking r2 score for Stochastic Gradient Descent Regressor
SGD = SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predSGD))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predSGD))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predSGD))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predSGD)))
# Out:
# R2_score: 0.9219356195996721
# MAE: 2.9477462525750298
# MSE: 11.202720466338413
# RMSE: 3.347046528857705

# %% [markdown]
# # Check for cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
#checking cv score for linear regression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.35781474348785447

# %%
#checking cv score for ridge regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.35598479023741936

# %%
#checking cv score for lasso regression
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.5163276962133869

# %%
#checking cv score for sgd regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.3703527904195

# %% [markdown]
# from R2 and cross val score values, we can conclude that lasso regression best fit the models

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regresssor
parameters = {'alpha':[0.01,0.1,1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV = GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 100}

# %%
# Creating Final Model
Baseball = Lasso(alpha=0.1,fit_intercept='bool',max_iter=10,selection='random',tol=1000)
Baseball.fit(x_train,y_train)
pred = Baseball.predict(x_test)
print('R2_score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 86.42951302468397
# RMSE value: 4.41299065192299

# %% [markdown]
# # Saving the model

# %%
#saving the model 
import joblib
joblib.dump(Baseball,'Baseball.pkl')
# Out:
# ['Baseball.pkl']

# %%
loadmodel = joblib.load('Baseball.pkl')

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(loadmodel.predict(x_test))
df_final = pd.DataFrame({"Original":a,"Predicted":predicted},index=range(len(a)))
df_final
# Out:
#    Original  Predicted
# 0        68  70.076267
# 1        78  80.594665
# 2        74  76.396027
# 3        88  82.827379
# 4        68  74.585015
# 5        64  73.395727
# 6        92  85.711108
# 7        90  87.337233
# 8       100  92.080846
